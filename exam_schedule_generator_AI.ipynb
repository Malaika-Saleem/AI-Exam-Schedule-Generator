# %%
import numpy as np
import pandas as pd
import random


# Helper functions
def check_teacher_availability(schedule, teacher, exam_day, start_hour):
    for _, value in schedule.items():
        if value[0] == teacher and value[2] == exam_day and value[3] == start_hour:
            return False
    return True

def check_teacher_consecutive_exams(schedule, teacher, exam_day):
    previous_exam = None
    for _, value in schedule.items():
        if value[0] == teacher and value[2] == exam_day:
            if previous_exam is not None:
                # Check if the current hour is 1 and the previous hour is 12
                if value[3] == 1 and previous_exam[3] == 12:
                    return False  # Consecutive exams
                # Check if the current hour is one hour ahead of the previous hour
                elif value[3] == previous_exam[3] + 1:
                    return False  # Consecutive exams
            # Check if the current hour is 9, indicating the start of the working hours
            elif value[3] < 9:
                return False  # Exam starts before 9 AM
            previous_exam = value
    return True


def generate_student_list(studentCourses):
    # Initialize an empty dictionary to store student names for each course code
    student_dict = {course: [] for course in courses}

    # Traverse studentCourse df
    for index, row in studentCourses.iterrows():
        course_code = row['Course Code']
        student_name = row['Student Name']
        # Append the student name to the list corresponding to the course code
        student_dict[course_code].append(student_name)
    return student_dict

def calculate_fitness(schedule, student_list):
    # Initialize fitness score
    fitness = 0
    
    # Apply penalty for additional constraints
    fitness += apply_additional_constraints(schedule)  
    
    # Loop through each teacher in the schedule
    for teacher in set([value[0] for value in schedule.values()]):
        # Get unique exam days for the teacher
        exam_days = set([value[2] for key, value in schedule.items() if value[0] == teacher])
        
        # Check consecutive exams and maximum exams per day constraints
        for exam_day in exam_days:
            # Penalize if teacher has non-consecutive exams
            if not check_teacher_consecutive_exams(schedule, teacher, exam_day):
                fitness -= 1
                
            # Penalize if teacher has more exams than the maximum allowed per day
            exams_on_day = [value for key, value in schedule.items() if value[0] == teacher and value[2] == exam_day]
            if len(exams_on_day) > MAX_EXAMS_PER_DAY:
                fitness -= 1
    
    return fitness


def apply_additional_constraints(schedule):
    fitness = 0
    
    # Constraint 1: No exams on Friday from 1-2
    friday_break = ('Friday', 1)
    for key, value in schedule.items():
        if value[2:] == friday_break:
            fitness -= 1
    
# Constraint 2: No student shall give more than 1 exam consecutively
    consecutive_exams = {}
    for key, value in schedule.items():
        student = key.split()[0]  # Extract student name from course code
        exam_hour = value[3]  # Extract exam hour from the schedule

        # Special case: if the exam hour is 1, adjust the previous exam hour to 12
        if exam_hour == 1:
            prev_exam_hour = 12
        else:
            prev_exam_hour = exam_hour - 1
    
        if student in consecutive_exams:
            if prev_exam_hour == 12 and exam_hour == 1:
                fitness -= 1  # Penalize fitness for consecutive exams
            elif prev_exam_hour == exam_hour - 1:
                fitness -= 1  # Penalize fitness for consecutive exams
                consecutive_exams[student] = exam_hour  # Store the current exam hour for the student

    
    # Constraint 3: Prioritize MG course exams before CS course exams for students enrolled in both
    mg_first = {}
    for key, value in schedule.items():
        student = key.split()[0]  # Extract student name from course code
        if 'MG' in key:
            mg_first[student] = value
        elif 'CS' in key:
            if student in mg_first:
                mg_exam_day = mg_first[student][2]
                cs_exam_day = value[2]
                if days.index(mg_exam_day) > days.index(cs_exam_day):
                    fitness -= 1

    # Constraint 4: Two-hour break with half the faculty free in one slot and the rest in the other
    half_faculty = len(teachers) // 2
    available_hours = [hour for hour in hours if hour not in [1, 2]]
    for day in days:
        for hour in available_hours:
            free_teachers = 0
            for teacher in teachers:
                if check_teacher_availability(schedule, teacher, day, hour):
                    free_teachers += 1
            if free_teachers >= half_faculty:
                break
        else:
            fitness -= 1

    return fitness

def generate_valid_schedule():
    while True:
        schedule = {} #initialize dictionary
        for course in courses: #generate schedule on the basis of course list
            teacher = np.random.choice(teachers) #select random teacher
            room = np.random.choice(classroom) #select random room
            exam_day = np.random.choice(days) #select random day
            start_hour = np.random.choice(hours) #select random hour
            schedule[course] = (teacher, room, exam_day, start_hour) #append all these with course as key
        
        if apply_additional_constraints(schedule): #if schedule satisfies the constraints then return the schedule else dont
            return schedule
            
def roulette_wheel_selection(population, fitness_values):
    avg_fitness = sum(fitness_values)/26  #calculate the avg of fitness values
    probabilities = [fitness /avg_fitness for fitness in fitness_values]  #calculate probabilies by dividing every fitness by avg of fitness
    rand_value = random.uniform(0, 1)  #selects a random floating point value
    cumulative_probability = 0
    for i, probability in enumerate(probabilities):
        cumulative_probability += probability  # generating number line of problablity
        if rand_value <= cumulative_probability: #if random value is within the current schedule 
            return population[i]   #then return that schedule
        

def crossover(parent1, parent2):
    crossover_point = 3  #defining a fixed crossover point
    offspring1 = {}
    offspring2 = {}
    for index, (course, details) in enumerate(parent1.items()): #iterating through parent 1
        if index < crossover_point: #if index is less than crossover point
            offspring1[course] = details #then store the details of parent1 in offspring 1
            offspring2[course] = parent2[course] #and store the details of parent2 in offspring 2
        else: #else if index is greater than crossover point
            offspring1[course] = parent2[course]#then store the details of parent1 in offspring 1
            offspring2[course] = details#and store the details of parent2 in offspring 2
    return offspring1,offspring2

def mutate(schedule):
    mutated_schedule = schedule.copy() 
    course_to_mutate = random.choice(list(mutated_schedule.keys())) #select a random course to mutate
    teacher = np.random.choice(teachers) #select random teacher
    room = np.random.choice(classroom)#select random room
    exam_day = np.random.choice(days)#select random exam day
    start_hour = np.random.choice(hours)#select random hour
    mutated_schedule[course_to_mutate] = (teacher, room, exam_day, start_hour) #edit the selected course in the whole schedule
    return mutated_schedule #and return


# Function to determine AM/PM based on hour value
def get_am_pm(hour):
    if hour in [9, 10, 11]:
        return 'AM'
    else:
        return 'PM'
    
    

def survivor_selection(population, student_list, mutation_rate):
    for _ in range(generation_count):  # Repeat survivor selection generation_count times
        # Perform constraints and calculate fitness values for the initial population
        fitness_values = [calculate_fitness(schedule, student_list) for schedule in population]
        

        # Apply roulette wheel selection
        selected_population = [roulette_wheel_selection(population, fitness_values) for _ in range(len(population))]

        # Apply crossover
        offspring_population = []  # Initialize an empty list to store offspring

        # Generate offspring by crossover
        for i in range(0, len(population), 2):
            # Select two parents for crossover
            parent1 = selected_population[i]
            parent2 = selected_population[i + 1]
        
            # Perform crossover to create two offspring
            offspring1, offspring2 = crossover(parent1, parent2)
        
            # Add the offspring to the offspring population list
            offspring_population.extend([offspring1, offspring2])

        # Apply mutation
        for idx, offspring in enumerate(offspring_population):
            # Check if mutation occurs based on mutation rate
            if random.random() < mutation_rate:
                # Perform mutation
                offspring_population[idx] = mutate(offspring)

        # Perform survivor selection
        population = offspring_population  # Replace the current population with the offspring population

    # Calculate fitness values for the last generation
    fitness_values = [calculate_fitness(schedule, student_list) for schedule in population]

    # Find the index of the schedule with the highest fitness
    best_schedule_index = fitness_values.index(max(fitness_values))

    # Select the best schedule from the last generation
    best_schedule = population[best_schedule_index]

    # Calculate fitness value for the best schedule
    best_fitness = fitness_values[best_schedule_index]

    # Convert the best schedule into a DataFrame
    best_schedule_df = pd.DataFrame(best_schedule.items(), columns=['Course', 'Details'])

    # Split the 'Details' column into separate columns
    best_schedule_df[['Teacher', 'Room', 'Day', 'Hour']] = pd.DataFrame(best_schedule_df['Details'].tolist(), index=best_schedule_df.index)

    # Drop the 'Details' column
    best_schedule_df.drop(columns=['Details'], inplace=True)

    # Convert 'Hour' column to numeric
    best_schedule_df['Hour'] = best_schedule_df['Hour'].astype(int)

    # Add 'AM/PM' column based on hour value
    best_schedule_df['AM/PM'] = best_schedule_df['Hour'].apply(get_am_pm)

    return best_schedule_df, best_fitness


# Convert the best sch

#main function

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
hours = [9, 10, 11, 12, 1, 2, 3, 4, 5]
classroom = ['C-301', 'C-302', 'C-303', 'C-304', 'C-305', 'C-306', 'C-307', 'C-308', 'C-309', 'C-310']
COURSE_DURATION = 1
MAX_EXAMS_PER_DAY=3
population_size = 26
mutation_rate = 0.1  
generation_count=10

# Load data
data_courses = pd.read_csv('Dataset/courses.csv')
courses = data_courses['Course Code'].tolist() #convert to list

data_teachers = pd.read_csv('Dataset/teachers.csv')
teachers = data_teachers['Names'].tolist() #convert to list

data= pd.read_csv('Dataset/studentCourse.csv')
studentCourses=pd.DataFrame(data)


# Main genetic algorithm

student_list = generate_student_list(studentCourses) #generate student list

population = [generate_valid_schedule() for _ in range(population_size)] #initialize population with valid schedules

# Check constraints and calculate fitness for initial population
fitness_values = [calculate_fitness(schedule, student_list) for schedule in population]

# Initial Population
print("Initial Population:")
for index, (schedule, fitness) in enumerate(zip(population, fitness_values)):
    print("Schedule:", index + 1)
    print("Fitness Value:", fitness)  # Print the fitness value for this schedule
    for course, details in schedule.items():
        print("Course: {}, Teacher: {}, Room: {}, Day: {}, Hour: {}".format(course, details[0], details[1], details[2], details[3]))
    print()

# Apply roulette wheel selection
selected_population = [roulette_wheel_selection(population, fitness_values) for _ in range(26)]


# Selected Population
print("\nSelected Population:")
for index, schedule in enumerate(selected_population):
    fitness_value = fitness_values[index]  # Get the fitness value for this schedule
    print("Schedule:", index + 1)
    print("Fitness Value:", fitness_value)  # Print the fitness value
    for course, details in schedule.items():
        print("Course: {}, Teacher: {}, Room: {}, Day: {}, Hour: {}".format(course, details[0], details[1], details[2], details[3]))
    print()

# Apply crossover
offspring_population = []
for i in range(0, 26, 2):
    parent1 = selected_population[i]
    parent2 = selected_population[i + 1]
    offspring1, offspring2 = crossover(parent1, parent2)
    offspring_population.extend([offspring1, offspring2])

# Crossover Population
print("\nCrossover Population:")
for index, offspring in enumerate(offspring_population):
    fitness_value = calculate_fitness(offspring, student_list)  # Calculate fitness for this offspring
    print("Offspring:", index + 1)
    print("Fitness Value:", fitness_value)  # Print the fitness value
    for course, details in offspring.items():
        print("Course: {}, Teacher: {}, Room: {}, Day: {}, Hour: {}".format(course, details[0], details[1], details[2], details[3]))
    print()

# Apply mutation
for i, offspring in enumerate(offspring_population):
    if random.random() < mutation_rate:
        offspring_population[i] = mutate(offspring)

# Mutated Population
print("\nMutated Population:")
for index, offspring in enumerate(offspring_population):
    fitness_value = calculate_fitness(offspring, student_list)  # Calculate fitness for this offspring
    print("Offspring:", index + 1)
    print("Fitness Value:", fitness_value)  # Print the fitness value
    for course, details in offspring.items():
        print("Course: {}, Teacher: {}, Room: {}, Day: {}, Hour: {}".format(course, details[0], details[1], details[2], details[3]))
    print()



# Usage example:
best_schedule_df, best_fitness = survivor_selection(population, student_list, mutation_rate)
# Print the best schedule with its fitness value
print("\nBest Schedule (DataFrame) - Fitness Value:", best_fitness)
print("\nBest Schedule (DataFrame):")
print(best_schedule_df)
# Group the DataFrame by week days and sort the values within each group by 'Hour'
grouped_schedule = best_schedule_df.sort_values(by=['Day', 'Hour']).groupby('Day')

# Display the schedules for each day with corrected index
for day, schedule in grouped_schedule:
    # Reset the index starting from 1 for each group
    schedule.reset_index(drop=True, inplace=True)
    
    print(f"\n{day} Schedule:")
    print(schedule)
# Out:
# Initial Population:
# Schedule: 1
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Schedule: 2
# Fitness Value: -13
# Course: CS217, Teacher: Usman Ashraf, Room: C-308, Day: Wednesday, Hour: 10
# Course: EE227, Teacher: Farah Naz, Room: C-308, Day: Thursday, Hour: 4
# Course: CS211, Teacher: Kashif Munir, Room: C-309, Day: Thursday, Hour: 3
# Course: SE110, Teacher: Amna Irum, Room: C-304, Day: Friday, Hour: 3
# Course: CS118, Teacher: Tayyaba Zainab, Room: C-305, Day: Monday, Hour: 2
# Course: CS219, Teacher: Tayyaba Zainab, Room: C-303, Day: Monday, Hour: 1
# Course: CS220, Teacher: Asma Nisa, Room: C-301, Day: Monday, Hour: 11
# Course: CS302, Teacher: Hassan Mustafa, Room: C-301, Day: Thursday, Hour: 5
# Course: CY2012, Teacher: Bilal Khalid, Room: C-306, Day: Thursday, Hour: 10
# Course: CS307, Teacher: Shafaq Riaz, Room: C-306, Day: Monday, Hour: 3
# Course: CS328, Teacher: Sajid Khan, Room: C-301, Day: Thursday, Hour: 9
# Course: EE229, Teacher: Naveed Ahmad, Room: C-304, Day: Monday, Hour: 12
# Course: AI2011, Teacher: Rohail Gulbaz, Room: C-307, Day: Wednesday, Hour: 2
# Course: DS3011, Teacher: Sumera Abbas, Room: C-310, Day: Tuesday, Hour: 10
# Course: CS218, Teacher: Asma Nisa, Room: C-303, Day: Monday, Hour: 5
# Course: MT224, Teacher: Muhammad Asim, Room: C-304, Day: Friday, Hour: 1
# Course: SS113, Teacher: Sidra Khalid, Room: C-310, Day: Wednesday, Hour: 3
# Course: MG220, Teacher: Sajid Khan, Room: C-303, Day: Wednesday, Hour: 11
# Course: MG223, Teacher: Waqas Munir, Room: C-304, Day: Monday, Hour: 5
# Course: SS111, Teacher: Farah Naz, Room: C-303, Day: Tuesday, Hour: 1
# Course: SS152, Teacher: Tayyab Nadeem, Room: C-303, Day: Tuesday, Hour: 9
# Course: SS118, Teacher: Mehwish Hassan, Room: C-310, Day: Wednesday, Hour: 1
# Course: MT205, Teacher: Mehwish Hassan, Room: C-307, Day: Monday, Hour: 10
#
# Schedule: 3
# Fitness Value: -13
# Course: CS217, Teacher: Noreen Jamil, Room: C-304, Day: Friday, Hour: 9
# Course: EE227, Teacher: Noor ul Ain, Room: C-304, Day: Friday, Hour: 1
# Course: CS211, Teacher: Aqeel Shahzad, Room: C-309, Day: Monday, Hour: 3
# Course: SE110, Teacher: Shehreyar Rashid, Room: C-308, Day: Wednesday, Hour: 2
# Course: CS118, Teacher: Sehrish Hassan, Room: C-307, Day: Tuesday, Hour: 5
# Course: CS219, Teacher: Tayyab Nadeem, Room: C-309, Day: Monday, Hour: 9
# Course: CS220, Teacher: Mehboobullah, Room: C-305, Day: Monday, Hour: 9
# Course: CS302, Teacher: Nagina Safdar, Room: C-301, Day: Tuesday, Hour: 2
# Course: CY2012, Teacher: Faisal Cheema, Room: C-304, Day: Tuesday, Hour: 9
# Course: CS307, Teacher: Asif Naeem, Room: C-303, Day: Wednesday, Hour: 3
# Course: CS328, Teacher: Subhan Ullah, Room: C-307, Day: Wednesday, Hour: 12
# Course: EE229, Teacher: Sajid Khan, Room: C-307, Day: Wednesday, Hour: 3
# Course: AI2011, Teacher: Kashif Munir, Room: C-306, Day: Tuesday, Hour: 12
# Course: DS3011, Teacher: Umair Arshad, Room: C-304, Day: Friday, Hour: 1
# Course: CS218, Teacher: Mehreen Alam, Room: C-301, Day: Friday, Hour: 11
# Course: MT224, Teacher: Sidra Khalid, Room: C-310, Day: Monday, Hour: 9
# Course: SS113, Teacher: Shahzad Mehmood, Room: C-301, Day: Wednesday, Hour: 11
# Course: MG220, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 4
# Course: MG223, Teacher: Asma Nisa, Room: C-308, Day: Thursday, Hour: 9
# Course: SS111, Teacher: Muhammad Usman, Room: C-302, Day: Friday, Hour: 10
# Course: SS152, Teacher: Shahzad Mehmood, Room: C-310, Day: Tuesday, Hour: 12
# Course: SS118, Teacher: Rohail Gulbaz, Room: C-309, Day: Thursday, Hour: 5
# Course: MT205, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 1
#
# Schedule: 4
# Fitness Value: -13
# Course: CS217, Teacher: Muhammad Usman, Room: C-305, Day: Friday, Hour: 1
# Course: EE227, Teacher: Shahzad Mehmood, Room: C-308, Day: Monday, Hour: 3
# Course: CS211, Teacher: Hamda Khan, Room: C-303, Day: Monday, Hour: 10
# Course: SE110, Teacher: Maheen Arshad, Room: C-304, Day: Friday, Hour: 9
# Course: CS118, Teacher: Shehreyar Rashid, Room: C-303, Day: Thursday, Hour: 4
# Course: CS219, Teacher: Shafaq Riaz, Room: C-308, Day: Monday, Hour: 5
# Course: CS220, Teacher: Amna Irum, Room: C-306, Day: Tuesday, Hour: 12
# Course: CS302, Teacher: Ayesha Bano, Room: C-302, Day: Monday, Hour: 9
# Course: CY2012, Teacher: Hasan Mujtaba, Room: C-302, Day: Wednesday, Hour: 4
# Course: CS307, Teacher: Usman Ashraf, Room: C-308, Day: Monday, Hour: 2
# Course: CS328, Teacher: Hassan Raza, Room: C-309, Day: Thursday, Hour: 10
# Course: EE229, Teacher: Adnan Tariq, Room: C-301, Day: Monday, Hour: 11
# Course: AI2011, Teacher: Naveed Ahmad, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Hassan Mustafa, Room: C-307, Day: Tuesday, Hour: 9
# Course: CS218, Teacher: Tayyaba Zainab, Room: C-305, Day: Wednesday, Hour: 2
# Course: MT224, Teacher: Sajid Khan, Room: C-303, Day: Monday, Hour: 4
# Course: SS113, Teacher: Rohail Gulbaz, Room: C-306, Day: Tuesday, Hour: 3
# Course: MG220, Teacher: Waseem Shahzad, Room: C-301, Day: Thursday, Hour: 3
# Course: MG223, Teacher: Usman Ashraf, Room: C-306, Day: Monday, Hour: 11
# Course: SS111, Teacher: Hammad Majeed, Room: C-306, Day: Tuesday, Hour: 9
# Course: SS152, Teacher: Behjat Zuhaira, Room: C-307, Day: Tuesday, Hour: 9
# Course: SS118, Teacher: Usman Ashraf, Room: C-301, Day: Wednesday, Hour: 5
# Course: MT205, Teacher: Irum Inayat, Room: C-307, Day: Tuesday, Hour: 3
#
# Schedule: 5
# Fitness Value: -11
# Course: CS217, Teacher: Mehboobullah, Room: C-303, Day: Thursday, Hour: 10
# Course: EE227, Teacher: Hassan Raza, Room: C-309, Day: Thursday, Hour: 2
# Course: CS211, Teacher: Zeeshan Qaiser, Room: C-304, Day: Wednesday, Hour: 1
# Course: SE110, Teacher: Usman Rashid, Room: C-302, Day: Tuesday, Hour: 4
# Course: CS118, Teacher: Sanaa Ilyas, Room: C-305, Day: Monday, Hour: 2
# Course: CS219, Teacher: Irum Inayat, Room: C-305, Day: Wednesday, Hour: 10
# Course: CS220, Teacher: Arshad Islam, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Mustafa, Room: C-305, Day: Thursday, Hour: 10
# Course: CY2012, Teacher: Sadia Nauman, Room: C-306, Day: Tuesday, Hour: 9
# Course: CS307, Teacher: Sidra Khalid, Room: C-310, Day: Friday, Hour: 1
# Course: CS328, Teacher: Shams Farooq, Room: C-301, Day: Thursday, Hour: 12
# Course: EE229, Teacher: Ayesha Bano, Room: C-305, Day: Tuesday, Hour: 4
# Course: AI2011, Teacher: Asif Naeem, Room: C-302, Day: Friday, Hour: 9
# Course: DS3011, Teacher: Sehrish Hassan, Room: C-309, Day: Tuesday, Hour: 4
# Course: CS218, Teacher: Javaria Imtiaz, Room: C-306, Day: Tuesday, Hour: 11
# Course: MT224, Teacher: Mehwish Hassan, Room: C-302, Day: Friday, Hour: 3
# Course: SS113, Teacher: Waqas Munir, Room: C-301, Day: Monday, Hour: 11
# Course: MG220, Teacher: Behjat Zuhaira, Room: C-301, Day: Tuesday, Hour: 4
# Course: MG223, Teacher: Sehrish Hassan, Room: C-301, Day: Monday, Hour: 9
# Course: SS111, Teacher: Farah Jabeen Awan, Room: C-302, Day: Tuesday, Hour: 11
# Course: SS152, Teacher: Hamda Khan, Room: C-308, Day: Thursday, Hour: 4
# Course: SS118, Teacher: Shoaib Mehboob, Room: C-301, Day: Wednesday, Hour: 9
# Course: MT205, Teacher: Khadija Farooq, Room: C-309, Day: Friday, Hour: 12
#
# Schedule: 6
# Fitness Value: -13
# Course: CS217, Teacher: Mehwish Hassan, Room: C-303, Day: Thursday, Hour: 3
# Course: EE227, Teacher: Asif Naeem, Room: C-306, Day: Monday, Hour: 10
# Course: CS211, Teacher: Aqeel Shahzad, Room: C-301, Day: Friday, Hour: 9
# Course: SE110, Teacher: Mehwish Hassan, Room: C-301, Day: Friday, Hour: 1
# Course: CS118, Teacher: Shams Farooq, Room: C-310, Day: Thursday, Hour: 4
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-308, Day: Thursday, Hour: 4
# Course: CS220, Teacher: Tayyaba Zainab, Room: C-309, Day: Wednesday, Hour: 11
# Course: CS302, Teacher: Tayyab Nadeem, Room: C-308, Day: Monday, Hour: 10
# Course: CY2012, Teacher: Tayyaba Zainab, Room: C-310, Day: Thursday, Hour: 2
# Course: CS307, Teacher: Adnan Tariq, Room: C-301, Day: Thursday, Hour: 3
# Course: CS328, Teacher: Nagina Safdar, Room: C-310, Day: Wednesday, Hour: 5
# Course: EE229, Teacher: Asma Nisa, Room: C-309, Day: Tuesday, Hour: 10
# Course: AI2011, Teacher: Sajid Khan, Room: C-306, Day: Friday, Hour: 11
# Course: DS3011, Teacher: Shams Farooq, Room: C-302, Day: Thursday, Hour: 10
# Course: CS218, Teacher: Behjat Zuhaira, Room: C-308, Day: Thursday, Hour: 2
# Course: MT224, Teacher: Muhammad Asim, Room: C-305, Day: Monday, Hour: 11
# Course: SS113, Teacher: Khadija Farooq, Room: C-309, Day: Friday, Hour: 9
# Course: MG220, Teacher: Shams Farooq, Room: C-309, Day: Wednesday, Hour: 9
# Course: MG223, Teacher: Mehwish Hassan, Room: C-301, Day: Friday, Hour: 9
# Course: SS111, Teacher: Asif Naeem, Room: C-302, Day: Thursday, Hour: 3
# Course: SS152, Teacher: Javaria Imtiaz, Room: C-305, Day: Wednesday, Hour: 5
# Course: SS118, Teacher: Amna Irum, Room: C-301, Day: Monday, Hour: 1
# Course: MT205, Teacher: Maheen Arshad, Room: C-310, Day: Tuesday, Hour: 5
#
# Schedule: 7
# Fitness Value: -12
# Course: CS217, Teacher: Noreen Jamil, Room: C-304, Day: Friday, Hour: 5
# Course: EE227, Teacher: Kifayat Ullah, Room: C-305, Day: Thursday, Hour: 2
# Course: CS211, Teacher: Sidra Khalid, Room: C-310, Day: Monday, Hour: 11
# Course: SE110, Teacher: Ayesha Bano, Room: C-301, Day: Friday, Hour: 12
# Course: CS118, Teacher: Asif Naeem, Room: C-306, Day: Monday, Hour: 1
# Course: CS219, Teacher: Waseem Shahzad, Room: C-309, Day: Monday, Hour: 5
# Course: CS220, Teacher: Zohaib Iqbal, Room: C-304, Day: Wednesday, Hour: 9
# Course: CS302, Teacher: Zainab Moin, Room: C-307, Day: Monday, Hour: 11
# Course: CY2012, Teacher: Shoaib Mehboob, Room: C-304, Day: Wednesday, Hour: 10
# Course: CS307, Teacher: Waqas Munir, Room: C-306, Day: Thursday, Hour: 3
# Course: CS328, Teacher: Adnan Tariq, Room: C-307, Day: Monday, Hour: 11
# Course: EE229, Teacher: Umair Arshad, Room: C-310, Day: Friday, Hour: 3
# Course: AI2011, Teacher: Zohaib Iqbal, Room: C-303, Day: Wednesday, Hour: 5
# Course: DS3011, Teacher: Nagina Safdar, Room: C-305, Day: Tuesday, Hour: 10
# Course: CS218, Teacher: Ayesha Bano, Room: C-308, Day: Monday, Hour: 9
# Course: MT224, Teacher: Usman Rashid, Room: C-301, Day: Wednesday, Hour: 10
# Course: SS113, Teacher: Farah Naz, Room: C-308, Day: Tuesday, Hour: 4
# Course: MG220, Teacher: Sidra Khalid, Room: C-303, Day: Friday, Hour: 1
# Course: MG223, Teacher: Ejaz Ahmed, Room: C-307, Day: Wednesday, Hour: 5
# Course: SS111, Teacher: Adnan Tariq, Room: C-308, Day: Tuesday, Hour: 9
# Course: SS152, Teacher: Khadija Farooq, Room: C-307, Day: Wednesday, Hour: 1
# Course: SS118, Teacher: Usman Ashraf, Room: C-308, Day: Monday, Hour: 11
# Course: MT205, Teacher: Sidra Khalid, Room: C-306, Day: Tuesday, Hour: 4
#
# Schedule: 8
# Fitness Value: -12
# Course: CS217, Teacher: Rohail Gulbaz, Room: C-303, Day: Monday, Hour: 9
# Course: EE227, Teacher: Waqas Munir, Room: C-306, Day: Wednesday, Hour: 10
# Course: CS211, Teacher: Asif Naeem, Room: C-310, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Zainab Moin, Room: C-305, Day: Wednesday, Hour: 11
# Course: CS118, Teacher: Zeeshan Qaiser, Room: C-310, Day: Tuesday, Hour: 5
# Course: CS219, Teacher: Asma Nisa, Room: C-310, Day: Monday, Hour: 1
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Thursday, Hour: 4
# Course: CS302, Teacher: Irum Inayat, Room: C-304, Day: Wednesday, Hour: 11
# Course: CY2012, Teacher: Noreen Jamil, Room: C-301, Day: Monday, Hour: 12
# Course: CS307, Teacher: Tayyaba Zainab, Room: C-301, Day: Monday, Hour: 10
# Course: CS328, Teacher: Farah Jabeen Awan, Room: C-310, Day: Friday, Hour: 1
# Course: EE229, Teacher: Tayyab Nadeem, Room: C-303, Day: Thursday, Hour: 2
# Course: AI2011, Teacher: Umair Arshad, Room: C-310, Day: Tuesday, Hour: 3
# Course: DS3011, Teacher: Farah Naz, Room: C-307, Day: Wednesday, Hour: 9
# Course: CS218, Teacher: Arshad Islam, Room: C-310, Day: Friday, Hour: 12
# Course: MT224, Teacher: Zainab Abaid, Room: C-301, Day: Wednesday, Hour: 12
# Course: SS113, Teacher: Kifayat Ullah, Room: C-304, Day: Friday, Hour: 12
# Course: MG220, Teacher: Hamda Khan, Room: C-308, Day: Thursday, Hour: 4
# Course: MG223, Teacher: Shahzad Mehmood, Room: C-307, Day: Thursday, Hour: 4
# Course: SS111, Teacher: Tayyaba Zainab, Room: C-306, Day: Thursday, Hour: 3
# Course: SS152, Teacher: Shoaib Mehboob, Room: C-306, Day: Wednesday, Hour: 4
# Course: SS118, Teacher: Sehrish Hassan, Room: C-305, Day: Friday, Hour: 4
# Course: MT205, Teacher: Zohaib Iqbal, Room: C-306, Day: Friday, Hour: 11
#
# Schedule: 9
# Fitness Value: -13
# Course: CS217, Teacher: Ejaz Ahmed, Room: C-309, Day: Monday, Hour: 9
# Course: EE227, Teacher: Sumera Abbas, Room: C-302, Day: Thursday, Hour: 2
# Course: CS211, Teacher: Maheen Arshad, Room: C-302, Day: Monday, Hour: 10
# Course: SE110, Teacher: Subhan Ullah, Room: C-302, Day: Friday, Hour: 2
# Course: CS118, Teacher: Hamda Khan, Room: C-308, Day: Wednesday, Hour: 1
# Course: CS219, Teacher: Waqas Munir, Room: C-310, Day: Tuesday, Hour: 1
# Course: CS220, Teacher: Sehrish Hassan, Room: C-301, Day: Tuesday, Hour: 10
# Course: CS302, Teacher: Irum Inayat, Room: C-307, Day: Thursday, Hour: 1
# Course: CY2012, Teacher: Kifayat Ullah, Room: C-304, Day: Tuesday, Hour: 5
# Course: CS307, Teacher: Aqeel Shahzad, Room: C-308, Day: Friday, Hour: 12
# Course: CS328, Teacher: Muhammad Usman, Room: C-307, Day: Tuesday, Hour: 11
# Course: EE229, Teacher: Kashif Munir, Room: C-310, Day: Monday, Hour: 10
# Course: AI2011, Teacher: Sumera Abbas, Room: C-309, Day: Wednesday, Hour: 9
# Course: DS3011, Teacher: Farah Jabeen Awan, Room: C-310, Day: Thursday, Hour: 2
# Course: CS218, Teacher: Irum Inayat, Room: C-305, Day: Thursday, Hour: 1
# Course: MT224, Teacher: Sara Aziz, Room: C-303, Day: Monday, Hour: 1
# Course: SS113, Teacher: Umair Arshad, Room: C-304, Day: Friday, Hour: 1
# Course: MG220, Teacher: Muhammad Asim, Room: C-305, Day: Tuesday, Hour: 4
# Course: MG223, Teacher: Zeeshan Qaiser, Room: C-304, Day: Thursday, Hour: 10
# Course: SS111, Teacher: Sidra Khalid, Room: C-308, Day: Wednesday, Hour: 11
# Course: SS152, Teacher: Javaria Imtiaz, Room: C-302, Day: Wednesday, Hour: 1
# Course: SS118, Teacher: Sajid Khan, Room: C-305, Day: Monday, Hour: 12
# Course: MT205, Teacher: Maimoona Rassol, Room: C-309, Day: Friday, Hour: 2
#
# Schedule: 10
# Fitness Value: -14
# Course: CS217, Teacher: Hammad Majeed, Room: C-309, Day: Thursday, Hour: 9
# Course: EE227, Teacher: Sumera Abbas, Room: C-310, Day: Friday, Hour: 9
# Course: CS211, Teacher: Farah Jabeen Awan, Room: C-310, Day: Monday, Hour: 4
# Course: SE110, Teacher: Ameen Chilwan, Room: C-307, Day: Friday, Hour: 1
# Course: CS118, Teacher: Shoaib Mehboob, Room: C-308, Day: Thursday, Hour: 1
# Course: CS219, Teacher: Waqas Munir, Room: C-310, Day: Tuesday, Hour: 11
# Course: CS220, Teacher: Hasan Mujtaba, Room: C-306, Day: Thursday, Hour: 3
# Course: CS302, Teacher: Subhan Ullah, Room: C-310, Day: Monday, Hour: 5
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-310, Day: Monday, Hour: 5
# Course: CS307, Teacher: Muhammad Asim, Room: C-309, Day: Tuesday, Hour: 5
# Course: CS328, Teacher: Sumera Abbas, Room: C-304, Day: Thursday, Hour: 12
# Course: EE229, Teacher: Gul e Aisha, Room: C-309, Day: Tuesday, Hour: 11
# Course: AI2011, Teacher: Sadia Nauman, Room: C-306, Day: Monday, Hour: 12
# Course: DS3011, Teacher: Ameen Chilwan, Room: C-304, Day: Thursday, Hour: 10
# Course: CS218, Teacher: Hamda Khan, Room: C-306, Day: Thursday, Hour: 4
# Course: MT224, Teacher: Ameen Chilwan, Room: C-304, Day: Monday, Hour: 4
# Course: SS113, Teacher: Umair Arshad, Room: C-305, Day: Monday, Hour: 4
# Course: MG220, Teacher: Adnan Tariq, Room: C-307, Day: Wednesday, Hour: 2
# Course: MG223, Teacher: Ejaz Ahmed, Room: C-303, Day: Friday, Hour: 3
# Course: SS111, Teacher: Zeeshan Qaiser, Room: C-304, Day: Tuesday, Hour: 12
# Course: SS152, Teacher: Subhan Ullah, Room: C-307, Day: Wednesday, Hour: 1
# Course: SS118, Teacher: Sajid Khan, Room: C-310, Day: Tuesday, Hour: 11
# Course: MT205, Teacher: Waseem Shahzad, Room: C-307, Day: Tuesday, Hour: 11
#
# Schedule: 11
# Fitness Value: -12
# Course: CS217, Teacher: Nagina Safdar, Room: C-304, Day: Monday, Hour: 3
# Course: EE227, Teacher: Zainab Moin, Room: C-308, Day: Tuesday, Hour: 12
# Course: CS211, Teacher: Aqeel Shahzad, Room: C-305, Day: Monday, Hour: 4
# Course: SE110, Teacher: Sumera Abbas, Room: C-310, Day: Wednesday, Hour: 9
# Course: CS118, Teacher: Javaria Imtiaz, Room: C-308, Day: Monday, Hour: 12
# Course: CS219, Teacher: Ayesha Bano, Room: C-303, Day: Friday, Hour: 5
# Course: CS220, Teacher: Faisal Cheema, Room: C-305, Day: Monday, Hour: 5
# Course: CS302, Teacher: Sidra Khalid, Room: C-310, Day: Monday, Hour: 1
# Course: CY2012, Teacher: Hassan Mustafa, Room: C-305, Day: Friday, Hour: 12
# Course: CS307, Teacher: Asif Naeem, Room: C-305, Day: Tuesday, Hour: 4
# Course: CS328, Teacher: Mehboobullah, Room: C-303, Day: Wednesday, Hour: 1
# Course: EE229, Teacher: Farah Jabeen Awan, Room: C-310, Day: Monday, Hour: 12
# Course: AI2011, Teacher: Naveed Ahmad, Room: C-305, Day: Friday, Hour: 5
# Course: DS3011, Teacher: Shams Farooq, Room: C-303, Day: Monday, Hour: 10
# Course: CS218, Teacher: Hasan Mujtaba, Room: C-301, Day: Friday, Hour: 12
# Course: MT224, Teacher: Hassan Mustafa, Room: C-307, Day: Thursday, Hour: 3
# Course: SS113, Teacher: Hassan Mustafa, Room: C-310, Day: Friday, Hour: 9
# Course: MG220, Teacher: Amna Irum, Room: C-305, Day: Wednesday, Hour: 9
# Course: MG223, Teacher: Khadija Farooq, Room: C-308, Day: Friday, Hour: 1
# Course: SS111, Teacher: Zohaib Iqbal, Room: C-303, Day: Wednesday, Hour: 10
# Course: SS152, Teacher: Waqas Munir, Room: C-305, Day: Tuesday, Hour: 11
# Course: SS118, Teacher: Mehboobullah, Room: C-309, Day: Monday, Hour: 11
# Course: MT205, Teacher: Kifayat Ullah, Room: C-309, Day: Tuesday, Hour: 5
#
# Schedule: 12
# Fitness Value: -16
# Course: CS217, Teacher: Tayyaba Zainab, Room: C-305, Day: Friday, Hour: 4
# Course: EE227, Teacher: Sara Aziz, Room: C-306, Day: Thursday, Hour: 4
# Course: CS211, Teacher: Zainab Moin, Room: C-307, Day: Friday, Hour: 1
# Course: SE110, Teacher: Farah Jabeen Awan, Room: C-309, Day: Monday, Hour: 10
# Course: CS118, Teacher: Muhammad Usman, Room: C-310, Day: Thursday, Hour: 1
# Course: CS219, Teacher: Muhammad Usman, Room: C-307, Day: Thursday, Hour: 12
# Course: CS220, Teacher: Kifayat Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: CS302, Teacher: Usman Rashid, Room: C-306, Day: Wednesday, Hour: 11
# Course: CY2012, Teacher: Aqeel Shahzad, Room: C-305, Day: Wednesday, Hour: 12
# Course: CS307, Teacher: Mehboobullah, Room: C-305, Day: Wednesday, Hour: 10
# Course: CS328, Teacher: Maimoona Rassol, Room: C-304, Day: Friday, Hour: 1
# Course: EE229, Teacher: Waqas Munir, Room: C-308, Day: Wednesday, Hour: 3
# Course: AI2011, Teacher: Mehreen Alam, Room: C-307, Day: Tuesday, Hour: 2
# Course: DS3011, Teacher: Zainab Abaid, Room: C-306, Day: Thursday, Hour: 9
# Course: CS218, Teacher: Sanaa Ilyas, Room: C-304, Day: Monday, Hour: 3
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Wednesday, Hour: 4
# Course: SS113, Teacher: Sidra Khalid, Room: C-310, Day: Friday, Hour: 2
# Course: MG220, Teacher: Ayesha Bano, Room: C-304, Day: Thursday, Hour: 2
# Course: MG223, Teacher: Zohaib Iqbal, Room: C-304, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-308, Day: Thursday, Hour: 3
# Course: SS152, Teacher: Farwa Batool, Room: C-302, Day: Tuesday, Hour: 9
# Course: SS118, Teacher: Hasan Mujtaba, Room: C-302, Day: Monday, Hour: 4
# Course: MT205, Teacher: Asif Naeem, Room: C-303, Day: Thursday, Hour: 2
#
# Schedule: 13
# Fitness Value: -14
# Course: CS217, Teacher: Sadia Nauman, Room: C-301, Day: Thursday, Hour: 2
# Course: EE227, Teacher: Usman Rashid, Room: C-305, Day: Monday, Hour: 1
# Course: CS211, Teacher: Hasan Mujtaba, Room: C-305, Day: Monday, Hour: 5
# Course: SE110, Teacher: Sanaa Ilyas, Room: C-304, Day: Friday, Hour: 1
# Course: CS118, Teacher: Amna Irum, Room: C-304, Day: Monday, Hour: 11
# Course: CS219, Teacher: Amna Irum, Room: C-302, Day: Tuesday, Hour: 2
# Course: CS220, Teacher: Hassan Raza, Room: C-310, Day: Wednesday, Hour: 11
# Course: CS302, Teacher: Sumera Abbas, Room: C-305, Day: Friday, Hour: 10
# Course: CY2012, Teacher: Sanaa Ilyas, Room: C-310, Day: Thursday, Hour: 3
# Course: CS307, Teacher: Farah Naz, Room: C-302, Day: Friday, Hour: 10
# Course: CS328, Teacher: Asif Naeem, Room: C-301, Day: Friday, Hour: 5
# Course: EE229, Teacher: Asif Naeem, Room: C-302, Day: Wednesday, Hour: 1
# Course: AI2011, Teacher: Mehreen Alam, Room: C-301, Day: Tuesday, Hour: 10
# Course: DS3011, Teacher: Muhammad bin Qasim, Room: C-302, Day: Friday, Hour: 3
# Course: CS218, Teacher: Hassan Mustafa, Room: C-307, Day: Monday, Hour: 5
# Course: MT224, Teacher: Ayesha Bano, Room: C-301, Day: Tuesday, Hour: 11
# Course: SS113, Teacher: Maimoona Rassol, Room: C-305, Day: Friday, Hour: 4
# Course: MG220, Teacher: Zainab Moin, Room: C-301, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Asma Nisa, Room: C-302, Day: Monday, Hour: 9
# Course: SS111, Teacher: Ejaz Ahmed, Room: C-302, Day: Thursday, Hour: 5
# Course: SS152, Teacher: Hasan Mujtaba, Room: C-305, Day: Monday, Hour: 5
# Course: SS118, Teacher: Irum Inayat, Room: C-302, Day: Thursday, Hour: 11
# Course: MT205, Teacher: Sadia Nauman, Room: C-306, Day: Friday, Hour: 12
#
# Schedule: 14
# Fitness Value: -17
# Course: CS217, Teacher: Zainab Moin, Room: C-303, Day: Thursday, Hour: 10
# Course: EE227, Teacher: Irum Inayat, Room: C-303, Day: Tuesday, Hour: 12
# Course: CS211, Teacher: Maheen Arshad, Room: C-308, Day: Wednesday, Hour: 2
# Course: SE110, Teacher: Muhammad Usman, Room: C-302, Day: Wednesday, Hour: 5
# Course: CS118, Teacher: Javaria Imtiaz, Room: C-301, Day: Monday, Hour: 1
# Course: CS219, Teacher: Sidra Khalid, Room: C-307, Day: Wednesday, Hour: 3
# Course: CS220, Teacher: Usman Rashid, Room: C-310, Day: Friday, Hour: 2
# Course: CS302, Teacher: Shams Farooq, Room: C-302, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Tayyaba Zainab, Room: C-303, Day: Wednesday, Hour: 5
# Course: CS307, Teacher: Maheen Arshad, Room: C-308, Day: Monday, Hour: 5
# Course: CS328, Teacher: Umair Arshad, Room: C-307, Day: Tuesday, Hour: 1
# Course: EE229, Teacher: Javaria Imtiaz, Room: C-302, Day: Monday, Hour: 1
# Course: AI2011, Teacher: Sadia Nauman, Room: C-306, Day: Tuesday, Hour: 3
# Course: DS3011, Teacher: Muhammad Usman, Room: C-302, Day: Friday, Hour: 12
# Course: CS218, Teacher: Maimoona Rassol, Room: C-303, Day: Tuesday, Hour: 5
# Course: MT224, Teacher: Maheen Arshad, Room: C-306, Day: Friday, Hour: 4
# Course: SS113, Teacher: Zainab Abaid, Room: C-302, Day: Tuesday, Hour: 1
# Course: MG220, Teacher: Shoaib Mehboob, Room: C-305, Day: Wednesday, Hour: 2
# Course: MG223, Teacher: Hassan Raza, Room: C-307, Day: Wednesday, Hour: 12
# Course: SS111, Teacher: Tayyaba Zainab, Room: C-309, Day: Thursday, Hour: 1
# Course: SS152, Teacher: Sehrish Hassan, Room: C-304, Day: Tuesday, Hour: 3
# Course: SS118, Teacher: Shehreyar Rashid, Room: C-301, Day: Wednesday, Hour: 9
# Course: MT205, Teacher: Usman Ashraf, Room: C-310, Day: Wednesday, Hour: 11
#
# Schedule: 15
# Fitness Value: -10
# Course: CS217, Teacher: Usman Rashid, Room: C-302, Day: Wednesday, Hour: 10
# Course: EE227, Teacher: Shoaib Mehboob, Room: C-306, Day: Wednesday, Hour: 9
# Course: CS211, Teacher: Bilal Khalid, Room: C-303, Day: Thursday, Hour: 1
# Course: SE110, Teacher: Shehreyar Rashid, Room: C-306, Day: Friday, Hour: 10
# Course: CS118, Teacher: Nagina Safdar, Room: C-302, Day: Thursday, Hour: 4
# Course: CS219, Teacher: Sidra Khalid, Room: C-305, Day: Monday, Hour: 10
# Course: CS220, Teacher: Maheen Arshad, Room: C-308, Day: Tuesday, Hour: 4
# Course: CS302, Teacher: Subhan Ullah, Room: C-309, Day: Monday, Hour: 5
# Course: CY2012, Teacher: Farwa Batool, Room: C-302, Day: Friday, Hour: 12
# Course: CS307, Teacher: Zainab Moin, Room: C-302, Day: Friday, Hour: 12
# Course: CS328, Teacher: Muhammad Usman, Room: C-302, Day: Friday, Hour: 9
# Course: EE229, Teacher: Mehboobullah, Room: C-305, Day: Friday, Hour: 12
# Course: AI2011, Teacher: Hassan Mustafa, Room: C-301, Day: Friday, Hour: 1
# Course: DS3011, Teacher: Rohail Gulbaz, Room: C-309, Day: Monday, Hour: 9
# Course: CS218, Teacher: Waseem Shahzad, Room: C-305, Day: Wednesday, Hour: 9
# Course: MT224, Teacher: Waqas Munir, Room: C-306, Day: Monday, Hour: 2
# Course: SS113, Teacher: Farah Naz, Room: C-309, Day: Wednesday, Hour: 11
# Course: MG220, Teacher: Kashif Munir, Room: C-303, Day: Monday, Hour: 2
# Course: MG223, Teacher: Hassan Mustafa, Room: C-307, Day: Monday, Hour: 4
# Course: SS111, Teacher: Hamda Khan, Room: C-305, Day: Wednesday, Hour: 9
# Course: SS152, Teacher: Javaria Imtiaz, Room: C-306, Day: Friday, Hour: 11
# Course: SS118, Teacher: Naveed Ahmad, Room: C-305, Day: Tuesday, Hour: 5
# Course: MT205, Teacher: Sehrish Hassan, Room: C-301, Day: Monday, Hour: 11
#
# Schedule: 16
# Fitness Value: -15
# Course: CS217, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 10
# Course: EE227, Teacher: Farwa Batool, Room: C-308, Day: Friday, Hour: 4
# Course: CS211, Teacher: Kifayat Ullah, Room: C-301, Day: Monday, Hour: 12
# Course: SE110, Teacher: Khadija Farooq, Room: C-310, Day: Tuesday, Hour: 11
# Course: CS118, Teacher: Shahzad Mehmood, Room: C-310, Day: Friday, Hour: 5
# Course: CS219, Teacher: Arshad Islam, Room: C-303, Day: Friday, Hour: 5
# Course: CS220, Teacher: Irum Inayat, Room: C-305, Day: Tuesday, Hour: 2
# Course: CS302, Teacher: Faisal Cheema, Room: C-305, Day: Tuesday, Hour: 4
# Course: CY2012, Teacher: Kashif Munir, Room: C-307, Day: Friday, Hour: 11
# Course: CS307, Teacher: Mehwish Hassan, Room: C-304, Day: Wednesday, Hour: 2
# Course: CS328, Teacher: Adnan Tariq, Room: C-310, Day: Thursday, Hour: 9
# Course: EE229, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 10
# Course: AI2011, Teacher: Waqas Munir, Room: C-305, Day: Tuesday, Hour: 5
# Course: DS3011, Teacher: Maheen Arshad, Room: C-308, Day: Thursday, Hour: 10
# Course: CS218, Teacher: Usman Ashraf, Room: C-308, Day: Monday, Hour: 2
# Course: MT224, Teacher: Shahzad Mehmood, Room: C-309, Day: Thursday, Hour: 4
# Course: SS113, Teacher: Sara Aziz, Room: C-309, Day: Thursday, Hour: 3
# Course: MG220, Teacher: Sajid Khan, Room: C-306, Day: Friday, Hour: 1
# Course: MG223, Teacher: Sehrish Hassan, Room: C-308, Day: Thursday, Hour: 5
# Course: SS111, Teacher: Usman Ashraf, Room: C-301, Day: Friday, Hour: 5
# Course: SS152, Teacher: Usman Rashid, Room: C-306, Day: Wednesday, Hour: 11
# Course: SS118, Teacher: Usman Ashraf, Room: C-302, Day: Tuesday, Hour: 12
# Course: MT205, Teacher: Ejaz Ahmed, Room: C-302, Day: Monday, Hour: 3
#
# Schedule: 17
# Fitness Value: -15
# Course: CS217, Teacher: Gul e Aisha, Room: C-309, Day: Tuesday, Hour: 12
# Course: EE227, Teacher: Farah Jabeen Awan, Room: C-308, Day: Thursday, Hour: 10
# Course: CS211, Teacher: Farwa Batool, Room: C-306, Day: Thursday, Hour: 5
# Course: SE110, Teacher: Sehrish Hassan, Room: C-309, Day: Thursday, Hour: 11
# Course: CS118, Teacher: Noor ul Ain, Room: C-305, Day: Thursday, Hour: 10
# Course: CS219, Teacher: Amna Irum, Room: C-302, Day: Tuesday, Hour: 12
# Course: CS220, Teacher: Kifayat Ullah, Room: C-310, Day: Tuesday, Hour: 12
# Course: CS302, Teacher: Sidra Khalid, Room: C-310, Day: Wednesday, Hour: 12
# Course: CY2012, Teacher: Hassan Mustafa, Room: C-309, Day: Friday, Hour: 12
# Course: CS307, Teacher: Umair Arshad, Room: C-307, Day: Thursday, Hour: 1
# Course: CS328, Teacher: Zainab Moin, Room: C-310, Day: Friday, Hour: 11
# Course: EE229, Teacher: Adnan Tariq, Room: C-310, Day: Wednesday, Hour: 11
# Course: AI2011, Teacher: Maheen Arshad, Room: C-309, Day: Thursday, Hour: 5
# Course: DS3011, Teacher: Noor ul Ain, Room: C-301, Day: Friday, Hour: 1
# Course: CS218, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 12
# Course: MT224, Teacher: Noor ul Ain, Room: C-309, Day: Tuesday, Hour: 2
# Course: SS113, Teacher: Muhammad bin Qasim, Room: C-310, Day: Monday, Hour: 1
# Course: MG220, Teacher: Amna Irum, Room: C-310, Day: Friday, Hour: 4
# Course: MG223, Teacher: Shehreyar Rashid, Room: C-310, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Ameen Chilwan, Room: C-301, Day: Friday, Hour: 1
# Course: SS152, Teacher: Faisal Cheema, Room: C-302, Day: Tuesday, Hour: 1
# Course: SS118, Teacher: Javaria Imtiaz, Room: C-303, Day: Friday, Hour: 1
# Course: MT205, Teacher: Usman Ashraf, Room: C-302, Day: Thursday, Hour: 3
#
# Schedule: 18
# Fitness Value: -10
# Course: CS217, Teacher: Farwa Batool, Room: C-307, Day: Thursday, Hour: 10
# Course: EE227, Teacher: Shafaq Riaz, Room: C-307, Day: Thursday, Hour: 9
# Course: CS211, Teacher: Kifayat Ullah, Room: C-308, Day: Wednesday, Hour: 1
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-301, Day: Friday, Hour: 9
# Course: CS118, Teacher: Noor ul Ain, Room: C-303, Day: Thursday, Hour: 10
# Course: CS219, Teacher: Sajid Khan, Room: C-308, Day: Thursday, Hour: 12
# Course: CS220, Teacher: Sajid Khan, Room: C-306, Day: Tuesday, Hour: 5
# Course: CS302, Teacher: Mehwish Hassan, Room: C-308, Day: Thursday, Hour: 12
# Course: CY2012, Teacher: Usman Rashid, Room: C-301, Day: Monday, Hour: 11
# Course: CS307, Teacher: Farwa Batool, Room: C-303, Day: Tuesday, Hour: 12
# Course: CS328, Teacher: Sehrish Hassan, Room: C-302, Day: Monday, Hour: 5
# Course: EE229, Teacher: Faisal Cheema, Room: C-303, Day: Tuesday, Hour: 3
# Course: AI2011, Teacher: Mehwish Hassan, Room: C-304, Day: Tuesday, Hour: 12
# Course: DS3011, Teacher: Muhammad Asim, Room: C-308, Day: Monday, Hour: 3
# Course: CS218, Teacher: Zainab Abaid, Room: C-303, Day: Tuesday, Hour: 10
# Course: MT224, Teacher: Sadia Nauman, Room: C-306, Day: Friday, Hour: 1
# Course: SS113, Teacher: Zeeshan Qaiser, Room: C-310, Day: Tuesday, Hour: 3
# Course: MG220, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 11
# Course: MG223, Teacher: Aqeel Shahzad, Room: C-302, Day: Tuesday, Hour: 5
# Course: SS111, Teacher: Hammad Majeed, Room: C-301, Day: Thursday, Hour: 9
# Course: SS152, Teacher: Behjat Zuhaira, Room: C-309, Day: Friday, Hour: 9
# Course: SS118, Teacher: Bilal Khalid, Room: C-309, Day: Tuesday, Hour: 5
# Course: MT205, Teacher: Sumera Abbas, Room: C-308, Day: Wednesday, Hour: 9
#
# Schedule: 19
# Fitness Value: -13
# Course: CS217, Teacher: Muhammad Usman, Room: C-307, Day: Thursday, Hour: 4
# Course: EE227, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 10
# Course: CS211, Teacher: Shafaq Riaz, Room: C-307, Day: Friday, Hour: 11
# Course: SE110, Teacher: Muhammad Asim, Room: C-305, Day: Monday, Hour: 10
# Course: CS118, Teacher: Mehreen Alam, Room: C-309, Day: Friday, Hour: 1
# Course: CS219, Teacher: Zainab Abaid, Room: C-309, Day: Monday, Hour: 11
# Course: CS220, Teacher: Bilal Khalid, Room: C-307, Day: Friday, Hour: 2
# Course: CS302, Teacher: Shehreyar Rashid, Room: C-303, Day: Tuesday, Hour: 5
# Course: CY2012, Teacher: Ameen Chilwan, Room: C-301, Day: Monday, Hour: 4
# Course: CS307, Teacher: Mehwish Hassan, Room: C-305, Day: Friday, Hour: 9
# Course: CS328, Teacher: Shahzad Mehmood, Room: C-306, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Subhan Ullah, Room: C-306, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Nagina Safdar, Room: C-308, Day: Thursday, Hour: 2
# Course: DS3011, Teacher: Muhammad Asim, Room: C-306, Day: Monday, Hour: 2
# Course: CS218, Teacher: Shehreyar Rashid, Room: C-305, Day: Thursday, Hour: 12
# Course: MT224, Teacher: Mehboobullah, Room: C-310, Day: Tuesday, Hour: 2
# Course: SS113, Teacher: Hasan Mujtaba, Room: C-302, Day: Friday, Hour: 3
# Course: MG220, Teacher: Shams Farooq, Room: C-303, Day: Wednesday, Hour: 11
# Course: MG223, Teacher: Sanaa Ilyas, Room: C-301, Day: Thursday, Hour: 9
# Course: SS111, Teacher: Zohaib Iqbal, Room: C-303, Day: Friday, Hour: 10
# Course: SS152, Teacher: Amna Irum, Room: C-308, Day: Monday, Hour: 3
# Course: SS118, Teacher: Waqas Munir, Room: C-302, Day: Wednesday, Hour: 3
# Course: MT205, Teacher: Sehrish Hassan, Room: C-310, Day: Tuesday, Hour: 10
#
# Schedule: 20
# Fitness Value: -11
# Course: CS217, Teacher: Muhammad Asim, Room: C-310, Day: Friday, Hour: 11
# Course: EE227, Teacher: Behjat Zuhaira, Room: C-309, Day: Wednesday, Hour: 3
# Course: CS211, Teacher: Farwa Batool, Room: C-304, Day: Wednesday, Hour: 4
# Course: SE110, Teacher: Javaria Imtiaz, Room: C-304, Day: Wednesday, Hour: 12
# Course: CS118, Teacher: Zeeshan Qaiser, Room: C-306, Day: Friday, Hour: 2
# Course: CS219, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 3
# Course: CS220, Teacher: Mehwish Hassan, Room: C-308, Day: Thursday, Hour: 9
# Course: CS302, Teacher: Asif Naeem, Room: C-305, Day: Friday, Hour: 11
# Course: CY2012, Teacher: Kifayat Ullah, Room: C-310, Day: Thursday, Hour: 2
# Course: CS307, Teacher: Zeeshan Qaiser, Room: C-309, Day: Monday, Hour: 9
# Course: CS328, Teacher: Hamda Khan, Room: C-308, Day: Monday, Hour: 9
# Course: EE229, Teacher: Arshad Islam, Room: C-309, Day: Thursday, Hour: 3
# Course: AI2011, Teacher: Rohail Gulbaz, Room: C-310, Day: Monday, Hour: 5
# Course: DS3011, Teacher: Ejaz Ahmed, Room: C-305, Day: Monday, Hour: 11
# Course: CS218, Teacher: Hassan Mustafa, Room: C-309, Day: Friday, Hour: 11
# Course: MT224, Teacher: Faisal Cheema, Room: C-301, Day: Friday, Hour: 10
# Course: SS113, Teacher: Tayyab Nadeem, Room: C-307, Day: Wednesday, Hour: 9
# Course: MG220, Teacher: Sadia Nauman, Room: C-304, Day: Wednesday, Hour: 2
# Course: MG223, Teacher: Shahzad Mehmood, Room: C-301, Day: Friday, Hour: 1
# Course: SS111, Teacher: Naveed Ahmad, Room: C-307, Day: Friday, Hour: 9
# Course: SS152, Teacher: Muhammad bin Qasim, Room: C-304, Day: Monday, Hour: 1
# Course: SS118, Teacher: Subhan Ullah, Room: C-309, Day: Monday, Hour: 11
# Course: MT205, Teacher: Behjat Zuhaira, Room: C-310, Day: Wednesday, Hour: 12
#
# Schedule: 21
# Fitness Value: -8
# Course: CS217, Teacher: Hassan Mustafa, Room: C-310, Day: Wednesday, Hour: 1
# Course: EE227, Teacher: Javaria Imtiaz, Room: C-309, Day: Wednesday, Hour: 9
# Course: CS211, Teacher: Shehreyar Rashid, Room: C-303, Day: Monday, Hour: 3
# Course: SE110, Teacher: Sehrish Hassan, Room: C-310, Day: Tuesday, Hour: 4
# Course: CS118, Teacher: Maimoona Rassol, Room: C-308, Day: Friday, Hour: 1
# Course: CS219, Teacher: Sadia Nauman, Room: C-306, Day: Tuesday, Hour: 10
# Course: CS220, Teacher: Khadija Farooq, Room: C-303, Day: Monday, Hour: 10
# Course: CS302, Teacher: Tayyaba Zainab, Room: C-301, Day: Thursday, Hour: 12
# Course: CY2012, Teacher: Aqeel Shahzad, Room: C-303, Day: Thursday, Hour: 9
# Course: CS307, Teacher: Noor ul Ain, Room: C-309, Day: Monday, Hour: 11
# Course: CS328, Teacher: Farwa Batool, Room: C-309, Day: Friday, Hour: 10
# Course: EE229, Teacher: Faisal Cheema, Room: C-303, Day: Tuesday, Hour: 9
# Course: AI2011, Teacher: Umair Arshad, Room: C-307, Day: Tuesday, Hour: 12
# Course: DS3011, Teacher: Mehreen Alam, Room: C-307, Day: Monday, Hour: 11
# Course: CS218, Teacher: Khadija Farooq, Room: C-303, Day: Tuesday, Hour: 10
# Course: MT224, Teacher: Shehreyar Rashid, Room: C-308, Day: Monday, Hour: 11
# Course: SS113, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 2
# Course: MG220, Teacher: Aqeel Shahzad, Room: C-303, Day: Thursday, Hour: 3
# Course: MG223, Teacher: Rohail Gulbaz, Room: C-304, Day: Wednesday, Hour: 9
# Course: SS111, Teacher: Irum Inayat, Room: C-306, Day: Monday, Hour: 3
# Course: SS152, Teacher: Hassan Raza, Room: C-308, Day: Tuesday, Hour: 5
# Course: SS118, Teacher: Asif Naeem, Room: C-305, Day: Wednesday, Hour: 9
# Course: MT205, Teacher: Sumera Abbas, Room: C-305, Day: Wednesday, Hour: 9
#
# Schedule: 22
# Fitness Value: -16
# Course: CS217, Teacher: Kifayat Ullah, Room: C-308, Day: Monday, Hour: 9
# Course: EE227, Teacher: Zainab Moin, Room: C-309, Day: Tuesday, Hour: 11
# Course: CS211, Teacher: Shahzad Mehmood, Room: C-301, Day: Monday, Hour: 5
# Course: SE110, Teacher: Irum Inayat, Room: C-304, Day: Friday, Hour: 1
# Course: CS118, Teacher: Sajid Khan, Room: C-308, Day: Monday, Hour: 11
# Course: CS219, Teacher: Bilal Khalid, Room: C-310, Day: Friday, Hour: 1
# Course: CS220, Teacher: Javaria Imtiaz, Room: C-307, Day: Thursday, Hour: 4
# Course: CS302, Teacher: Muhammad Asim, Room: C-304, Day: Tuesday, Hour: 12
# Course: CY2012, Teacher: Hammad Majeed, Room: C-305, Day: Wednesday, Hour: 3
# Course: CS307, Teacher: Maheen Arshad, Room: C-309, Day: Friday, Hour: 2
# Course: CS328, Teacher: Farah Jabeen Awan, Room: C-309, Day: Friday, Hour: 1
# Course: EE229, Teacher: Faisal Cheema, Room: C-306, Day: Friday, Hour: 10
# Course: AI2011, Teacher: Usman Ashraf, Room: C-304, Day: Thursday, Hour: 2
# Course: DS3011, Teacher: Usman Ashraf, Room: C-308, Day: Thursday, Hour: 5
# Course: CS218, Teacher: Hassan Mustafa, Room: C-305, Day: Tuesday, Hour: 4
# Course: MT224, Teacher: Muhammad bin Qasim, Room: C-304, Day: Monday, Hour: 11
# Course: SS113, Teacher: Asif Naeem, Room: C-310, Day: Friday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-306, Day: Tuesday, Hour: 9
# Course: MG223, Teacher: Naveed Ahmad, Room: C-306, Day: Thursday, Hour: 9
# Course: SS111, Teacher: Hamda Khan, Room: C-304, Day: Monday, Hour: 10
# Course: SS152, Teacher: Khadija Farooq, Room: C-308, Day: Tuesday, Hour: 5
# Course: SS118, Teacher: Waseem Shahzad, Room: C-305, Day: Monday, Hour: 9
# Course: MT205, Teacher: Shoaib Mehboob, Room: C-310, Day: Monday, Hour: 5
#
# Schedule: 23
# Fitness Value: -15
# Course: CS217, Teacher: Maheen Arshad, Room: C-303, Day: Friday, Hour: 4
# Course: EE227, Teacher: Javaria Imtiaz, Room: C-304, Day: Monday, Hour: 1
# Course: CS211, Teacher: Shafaq Riaz, Room: C-307, Day: Wednesday, Hour: 1
# Course: SE110, Teacher: Adnan Tariq, Room: C-308, Day: Tuesday, Hour: 12
# Course: CS118, Teacher: Ameen Chilwan, Room: C-305, Day: Thursday, Hour: 1
# Course: CS219, Teacher: Sidra Khalid, Room: C-310, Day: Wednesday, Hour: 2
# Course: CS220, Teacher: Hassan Raza, Room: C-310, Day: Tuesday, Hour: 3
# Course: CS302, Teacher: Faisal Cheema, Room: C-306, Day: Thursday, Hour: 5
# Course: CY2012, Teacher: Zainab Abaid, Room: C-309, Day: Tuesday, Hour: 12
# Course: CS307, Teacher: Irum Inayat, Room: C-301, Day: Wednesday, Hour: 5
# Course: CS328, Teacher: Arshad Islam, Room: C-308, Day: Friday, Hour: 10
# Course: EE229, Teacher: Sanaa Ilyas, Room: C-308, Day: Wednesday, Hour: 11
# Course: AI2011, Teacher: Amna Irum, Room: C-303, Day: Friday, Hour: 1
# Course: DS3011, Teacher: Shehreyar Rashid, Room: C-303, Day: Monday, Hour: 2
# Course: CS218, Teacher: Mehboobullah, Room: C-309, Day: Monday, Hour: 2
# Course: MT224, Teacher: Asma Nisa, Room: C-307, Day: Monday, Hour: 11
# Course: SS113, Teacher: Shafaq Riaz, Room: C-303, Day: Monday, Hour: 4
# Course: MG220, Teacher: Khadija Farooq, Room: C-303, Day: Monday, Hour: 11
# Course: MG223, Teacher: Shehreyar Rashid, Room: C-304, Day: Tuesday, Hour: 9
# Course: SS111, Teacher: Asif Naeem, Room: C-309, Day: Friday, Hour: 11
# Course: SS152, Teacher: Mehwish Hassan, Room: C-304, Day: Thursday, Hour: 1
# Course: SS118, Teacher: Maimoona Rassol, Room: C-302, Day: Monday, Hour: 12
# Course: MT205, Teacher: Sara Aziz, Room: C-310, Day: Monday, Hour: 4
#
# Schedule: 24
# Fitness Value: -15
# Course: CS217, Teacher: Hamda Khan, Room: C-307, Day: Wednesday, Hour: 1
# Course: EE227, Teacher: Amna Irum, Room: C-309, Day: Thursday, Hour: 3
# Course: CS211, Teacher: Hasan Mujtaba, Room: C-308, Day: Tuesday, Hour: 1
# Course: SE110, Teacher: Sanaa Ilyas, Room: C-304, Day: Friday, Hour: 5
# Course: CS118, Teacher: Bilal Khalid, Room: C-308, Day: Friday, Hour: 11
# Course: CS219, Teacher: Asif Naeem, Room: C-301, Day: Tuesday, Hour: 4
# Course: CS220, Teacher: Sanaa Ilyas, Room: C-306, Day: Friday, Hour: 1
# Course: CS302, Teacher: Ejaz Ahmed, Room: C-307, Day: Monday, Hour: 11
# Course: CY2012, Teacher: Ejaz Ahmed, Room: C-303, Day: Tuesday, Hour: 5
# Course: CS307, Teacher: Sumera Abbas, Room: C-302, Day: Wednesday, Hour: 1
# Course: CS328, Teacher: Khadija Farooq, Room: C-308, Day: Wednesday, Hour: 11
# Course: EE229, Teacher: Farah Naz, Room: C-303, Day: Thursday, Hour: 5
# Course: AI2011, Teacher: Asif Naeem, Room: C-309, Day: Friday, Hour: 4
# Course: DS3011, Teacher: Hasan Mujtaba, Room: C-305, Day: Tuesday, Hour: 1
# Course: CS218, Teacher: Maheen Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: MT224, Teacher: Zainab Moin, Room: C-304, Day: Friday, Hour: 11
# Course: SS113, Teacher: Shams Farooq, Room: C-305, Day: Friday, Hour: 2
# Course: MG220, Teacher: Zohaib Iqbal, Room: C-310, Day: Thursday, Hour: 2
# Course: MG223, Teacher: Mehreen Alam, Room: C-302, Day: Tuesday, Hour: 12
# Course: SS111, Teacher: Hammad Majeed, Room: C-308, Day: Monday, Hour: 9
# Course: SS152, Teacher: Farah Jabeen Awan, Room: C-308, Day: Thursday, Hour: 10
# Course: SS118, Teacher: Adnan Tariq, Room: C-309, Day: Wednesday, Hour: 2
# Course: MT205, Teacher: Gul e Aisha, Room: C-305, Day: Monday, Hour: 2
#
# Schedule: 25
# Fitness Value: -16
# Course: CS217, Teacher: Tayyaba Zainab, Room: C-308, Day: Wednesday, Hour: 1
# Course: EE227, Teacher: Sumera Abbas, Room: C-306, Day: Tuesday, Hour: 11
# Course: CS211, Teacher: Subhan Ullah, Room: C-308, Day: Tuesday, Hour: 4
# Course: SE110, Teacher: Subhan Ullah, Room: C-309, Day: Monday, Hour: 12
# Course: CS118, Teacher: Arshad Islam, Room: C-304, Day: Friday, Hour: 2
# Course: CS219, Teacher: Sanaa Ilyas, Room: C-308, Day: Thursday, Hour: 10
# Course: CS220, Teacher: Rohail Gulbaz, Room: C-309, Day: Wednesday, Hour: 2
# Course: CS302, Teacher: Sara Aziz, Room: C-306, Day: Wednesday, Hour: 3
# Course: CY2012, Teacher: Kifayat Ullah, Room: C-310, Day: Friday, Hour: 3
# Course: CS307, Teacher: Hassan Raza, Room: C-303, Day: Tuesday, Hour: 11
# Course: CS328, Teacher: Waqas Munir, Room: C-303, Day: Wednesday, Hour: 12
# Course: EE229, Teacher: Irum Inayat, Room: C-307, Day: Tuesday, Hour: 9
# Course: AI2011, Teacher: Gul e Aisha, Room: C-304, Day: Tuesday, Hour: 3
# Course: DS3011, Teacher: Shams Farooq, Room: C-307, Day: Thursday, Hour: 1
# Course: CS218, Teacher: Irum Inayat, Room: C-301, Day: Friday, Hour: 2
# Course: MT224, Teacher: Waqas Munir, Room: C-301, Day: Monday, Hour: 4
# Course: SS113, Teacher: Zohaib Iqbal, Room: C-304, Day: Wednesday, Hour: 5
# Course: MG220, Teacher: Gul e Aisha, Room: C-310, Day: Tuesday, Hour: 4
# Course: MG223, Teacher: Maheen Arshad, Room: C-303, Day: Monday, Hour: 9
# Course: SS111, Teacher: Sanaa Ilyas, Room: C-306, Day: Monday, Hour: 2
# Course: SS152, Teacher: Sehrish Hassan, Room: C-310, Day: Friday, Hour: 1
# Course: SS118, Teacher: Kashif Munir, Room: C-310, Day: Monday, Hour: 1
# Course: MT205, Teacher: Arshad Islam, Room: C-301, Day: Monday, Hour: 1
#
# Schedule: 26
# Fitness Value: -13
# Course: CS217, Teacher: Sumera Abbas, Room: C-307, Day: Friday, Hour: 4
# Course: EE227, Teacher: Muhammad Usman, Room: C-307, Day: Thursday, Hour: 12
# Course: CS211, Teacher: Mehboobullah, Room: C-301, Day: Tuesday, Hour: 11
# Course: SE110, Teacher: Shoaib Mehboob, Room: C-309, Day: Wednesday, Hour: 5
# Course: CS118, Teacher: Ameen Chilwan, Room: C-309, Day: Friday, Hour: 1
# Course: CS219, Teacher: Sadia Nauman, Room: C-308, Day: Tuesday, Hour: 5
# Course: CS220, Teacher: Javaria Imtiaz, Room: C-310, Day: Wednesday, Hour: 11
# Course: CS302, Teacher: Naveed Ahmad, Room: C-304, Day: Monday, Hour: 3
# Course: CY2012, Teacher: Adnan Tariq, Room: C-304, Day: Tuesday, Hour: 5
# Course: CS307, Teacher: Javaria Imtiaz, Room: C-302, Day: Tuesday, Hour: 4
# Course: CS328, Teacher: Nagina Safdar, Room: C-307, Day: Friday, Hour: 5
# Course: EE229, Teacher: Waseem Shahzad, Room: C-307, Day: Tuesday, Hour: 9
# Course: AI2011, Teacher: Hassan Raza, Room: C-302, Day: Tuesday, Hour: 12
# Course: DS3011, Teacher: Sanaa Ilyas, Room: C-305, Day: Monday, Hour: 3
# Course: CS218, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 3
# Course: MT224, Teacher: Ayesha Bano, Room: C-303, Day: Monday, Hour: 11
# Course: SS113, Teacher: Zainab Abaid, Room: C-304, Day: Monday, Hour: 9
# Course: MG220, Teacher: Mehboobullah, Room: C-308, Day: Thursday, Hour: 12
# Course: MG223, Teacher: Javaria Imtiaz, Room: C-303, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Noreen Jamil, Room: C-304, Day: Thursday, Hour: 1
# Course: SS152, Teacher: Zainab Abaid, Room: C-303, Day: Monday, Hour: 3
# Course: SS118, Teacher: Tayyab Nadeem, Room: C-303, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Asma Nisa, Room: C-309, Day: Wednesday, Hour: 3
#
#
# Selected Population:
# Schedule: 1
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Schedule: 2
# Fitness Value: -13
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# ...
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 20
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 21
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Hammad Majeed, Room: C-304, Day: Tuesday, Hour: 9
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 22
# Fitness Value: -13
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Muhammad bin Qasim, Room: C-301, Day: Thursday, Hour: 4
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 23
# Fitness Value: -13
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Amna Irum, Room: C-304, Day: Friday, Hour: 3
# Course: CS118, Teacher: Tayyaba Zainab, Room: C-305, Day: Monday, Hour: 2
# Course: CS219, Teacher: Tayyaba Zainab, Room: C-303, Day: Monday, Hour: 1
# Course: CS220, Teacher: Asma Nisa, Room: C-301, Day: Monday, Hour: 11
# Course: CS302, Teacher: Hassan Mustafa, Room: C-301, Day: Thursday, Hour: 5
# Course: CY2012, Teacher: Bilal Khalid, Room: C-306, Day: Thursday, Hour: 10
# Course: CS307, Teacher: Shafaq Riaz, Room: C-306, Day: Monday, Hour: 3
# Course: CS328, Teacher: Sajid Khan, Room: C-301, Day: Thursday, Hour: 9
# Course: EE229, Teacher: Naveed Ahmad, Room: C-304, Day: Monday, Hour: 12
# Course: AI2011, Teacher: Rohail Gulbaz, Room: C-307, Day: Wednesday, Hour: 2
# Course: DS3011, Teacher: Sumera Abbas, Room: C-310, Day: Tuesday, Hour: 10
# Course: CS218, Teacher: Asma Nisa, Room: C-303, Day: Monday, Hour: 5
# Course: MT224, Teacher: Muhammad Asim, Room: C-304, Day: Friday, Hour: 1
# Course: SS113, Teacher: Sidra Khalid, Room: C-310, Day: Wednesday, Hour: 3
# Course: MG220, Teacher: Sajid Khan, Room: C-303, Day: Wednesday, Hour: 11
# Course: MG223, Teacher: Waqas Munir, Room: C-304, Day: Monday, Hour: 5
# Course: SS111, Teacher: Farah Naz, Room: C-303, Day: Tuesday, Hour: 1
# Course: SS152, Teacher: Tayyab Nadeem, Room: C-303, Day: Tuesday, Hour: 9
# Course: SS118, Teacher: Mehwish Hassan, Room: C-310, Day: Wednesday, Hour: 1
# Course: MT205, Teacher: Mehwish Hassan, Room: C-307, Day: Monday, Hour: 10
#
# Offspring: 24
# Fitness Value: -12
# Course: CS217, Teacher: Usman Ashraf, Room: C-308, Day: Wednesday, Hour: 10
# Course: EE227, Teacher: Farah Naz, Room: C-308, Day: Thursday, Hour: 4
# Course: CS211, Teacher: Kashif Munir, Room: C-309, Day: Thursday, Hour: 3
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 25
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
#
# Offspring: 26
# Fitness Value: -12
# Course: CS217, Teacher: Gul e Aisha, Room: C-304, Day: Friday, Hour: 2
# Course: EE227, Teacher: Rohail Gulbaz, Room: C-306, Day: Thursday, Hour: 1
# Course: CS211, Teacher: Sajid Khan, Room: C-302, Day: Wednesday, Hour: 11
# Course: SE110, Teacher: Aqeel Shahzad, Room: C-303, Day: Friday, Hour: 10
# Course: CS118, Teacher: Behjat Zuhaira, Room: C-310, Day: Monday, Hour: 11
# Course: CS219, Teacher: Muhammad bin Qasim, Room: C-301, Day: Monday, Hour: 11
# Course: CS220, Teacher: Ejaz Ahmed, Room: C-310, Day: Monday, Hour: 9
# Course: CS302, Teacher: Hassan Raza, Room: C-310, Day: Friday, Hour: 1
# Course: CY2012, Teacher: Waseem Shahzad, Room: C-301, Day: Wednesday, Hour: 9
# Course: CS307, Teacher: Behjat Zuhaira, Room: C-308, Day: Tuesday, Hour: 3
# Course: CS328, Teacher: Hassan Raza, Room: C-302, Day: Thursday, Hour: 3
# Course: EE229, Teacher: Umair Arshad, Room: C-309, Day: Thursday, Hour: 1
# Course: AI2011, Teacher: Sara Aziz, Room: C-310, Day: Thursday, Hour: 10
# Course: DS3011, Teacher: Umair Arshad, Room: C-308, Day: Wednesday, Hour: 4
# Course: CS218, Teacher: Subhan Ullah, Room: C-309, Day: Friday, Hour: 12
# Course: MT224, Teacher: Usman Rashid, Room: C-307, Day: Monday, Hour: 9
# Course: SS113, Teacher: Usman Rashid, Room: C-308, Day: Monday, Hour: 1
# Course: MG220, Teacher: Mehreen Alam, Room: C-302, Day: Wednesday, Hour: 5
# Course: MG223, Teacher: Muhammad bin Qasim, Room: C-308, Day: Tuesday, Hour: 3
# Course: SS111, Teacher: Muhammad bin Qasim, Room: C-309, Day: Wednesday, Hour: 12
# Course: SS152, Teacher: Ejaz Ahmed, Room: C-305, Day: Tuesday, Hour: 4
# Course: SS118, Teacher: Muhammad Usman, Room: C-302, Day: Thursday, Hour: 12
# Course: MT205, Teacher: Waqas Munir, Room: C-309, Day: Monday, Hour: 1
# Best Schedule (DataFrame) - Fitness Value: -11
#
# Best Schedule (DataFrame):
#     Course             Teacher   Room        Day  Hour AM/PM
# 0    CS217         Gul e Aisha  C-304     Friday     2    PM
# 1    EE227       Rohail Gulbaz  C-306   Thursday     1    PM
# 2    CS211          Sajid Khan  C-302  Wednesday    11    AM
# 3    SE110       Aqeel Shahzad  C-303     Friday    10    AM
# 4    CS118      Behjat Zuhaira  C-310     Monday    11    AM
# 5    CS219  Muhammad bin Qasim  C-301     Monday    11    AM
# 6    CS220          Ejaz Ahmed  C-310     Monday     9    AM
# 7    CS302         Hassan Raza  C-310     Friday     1    PM
# 8   CY2012      Waseem Shahzad  C-301  Wednesday     9    AM
# 9    CS307      Behjat Zuhaira  C-308    Tuesday     3    PM
# 10   CS328         Hassan Raza  C-302   Thursday     3    PM
# 11   EE229         Zainab Moin  C-305  Wednesday    11    AM
# 12  AI2011           Sara Aziz  C-310   Thursday    10    AM
# 13  DS3011        Umair Arshad  C-308  Wednesday     4    PM
# 14   CS218        Subhan Ullah  C-309     Friday    12    PM
# 15   MT224        Usman Rashid  C-307     Monday     9    AM
# 16   SS113        Usman Rashid  C-308     Monday     1    PM
# 17   MG220        Mehreen Alam  C-302  Wednesday     5    PM
# 18   MG223  Muhammad bin Qasim  C-308    Tuesday     3    PM
# 19   SS111  Muhammad bin Qasim  C-309  Wednesday    12    PM
# 20   SS152          Ejaz Ahmed  C-305    Tuesday     4    PM
# 21   SS118      Muhammad Usman  C-302   Thursday    12    PM
# 22   MT205         Waqas Munir  C-309     Monday     1    PM
#
# Friday Schedule:
#   Course        Teacher   Room     Day  Hour AM/PM
# 0  CS302    Hassan Raza  C-310  Friday     1    PM
# 1  CS217    Gul e Aisha  C-304  Friday     2    PM
# 2  SE110  Aqeel Shahzad  C-303  Friday    10    AM
# 3  CS218   Subhan Ullah  C-309  Friday    12    PM
#
# Monday Schedule:
#   Course             Teacher   Room     Day  Hour AM/PM
# 0  SS113        Usman Rashid  C-308  Monday     1    PM
# 1  MT205         Waqas Munir  C-309  Monday     1    PM
# 2  CS220          Ejaz Ahmed  C-310  Monday     9    AM
# 3  MT224        Usman Rashid  C-307  Monday     9    AM
# 4  CS118      Behjat Zuhaira  C-310  Monday    11    AM
# 5  CS219  Muhammad bin Qasim  C-301  Monday    11    AM
#
# Thursday Schedule:
#    Course         Teacher   Room       Day  Hour AM/PM
# 0   EE227   Rohail Gulbaz  C-306  Thursday     1    PM
# 1   CS328     Hassan Raza  C-302  Thursday     3    PM
# 2  AI2011       Sara Aziz  C-310  Thursday    10    AM
# 3   SS118  Muhammad Usman  C-302  Thursday    12    PM
#
# Tuesday Schedule:
#   Course             Teacher   Room      Day  Hour AM/PM
# 0  CS307      Behjat Zuhaira  C-308  Tuesday     3    PM
# 1  MG223  Muhammad bin Qasim  C-308  Tuesday     3    PM
# 2  SS152          Ejaz Ahmed  C-305  Tuesday     4    PM
#
# Wednesday Schedule:
#    Course             Teacher   Room        Day  Hour AM/PM
# 0  DS3011        Umair Arshad  C-308  Wednesday     4    PM
# 1   MG220        Mehreen Alam  C-302  Wednesday     5    PM
# 2  CY2012      Waseem Shahzad  C-301  Wednesday     9    AM
# 3   CS211          Sajid Khan  C-302  Wednesday    11    AM
# 4   EE229         Zainab Moin  C-305  Wednesday    11    AM
# 5   SS111  Muhammad bin Qasim  C-309  Wednesday    12    PM
